# %% [markdown]
# # Finance Data Project

# %% [raw]
# We'll focus on bank stocks and see how they progressed throughout the financial crisis all the way to early 2018.

# %% [markdown]
# # Get the Data

# %% [markdown]
# The Imports

# %%
from pandas_datareader import data, wb
import pandas as pd
import numpy as np
import datetime
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# Data
# We will get stock information for the following banks:
# Bank of America
# CitiGroup
# Goldman Sachs
# JPMorgan Chase
# Morgan Stanley
# Wells Fargo

# %%
start=datetime.datetime(2006,1,1)
end=datetime.datetime(2018,1,1)

# %%
#Bank of America
BAC=data.DataReader('BAC','yahoo',start,end)
#CitiGroup
C=data.DataReader('C','yahoo',start,end)
#Goldman Sachs
GS=data.DataReader('GS','yahoo',start,end)
#JPMorgan Chase
JPM=data.DataReader('JPM','yahoo',start,end)
#Morgan Stanley
MS=data.DataReader('MS','yahoo',start,end)
#Wells Fargo
WFC=data.DataReader('WFC','yahoo',start,end)

# %%
BAC
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  47.180000  46.150002  46.919998  47.080002  16296700.0  34.811729
# 2006-01-04  47.240002  46.450001  47.000000  46.580002  17757900.0  34.442013
# 2006-01-05  46.830002  46.320000  46.580002  46.639999  14970700.0  34.486385
# 2006-01-06  46.910000  46.349998  46.799999  46.570000  12599800.0  34.434616
# 2006-01-09  46.970001  46.360001  46.720001  46.599998  15619400.0  34.456806
# ...               ...        ...        ...        ...         ...        ...
# 2017-12-22  30.030001  29.620001  29.980000  29.879999  54203000.0  28.112759
# 2017-12-26  29.940001  29.580000  29.740000  29.780001  42371200.0  28.018675
# 2017-12-27  29.730000  29.600000  29.660000  29.730000  35111800.0  27.971630
# 2017-12-28  29.820000  29.660000  29.730000  29.799999  37914900.0  28.037491
# 2017-12-29  29.879999  29.520000  29.850000  29.520000  40672000.0  27.774052
#
# [3020 rows x 6 columns]

# %%
#Create a list of the ticker symbols (as strings)  Call this list: tickers
tickers=['BAC','C','GS','JPM','MS','WFC']

# %%
#Use pd.concat to concatenate the bank dataframes together to a single data frame called bank_stocks.
bank_stocks=pd.concat([BAC,C,GS,JPM,MS,WFC],axis=1,keys=tickers)

# %%
bank_stocks
# Out:
#                   BAC                                                          \
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  47.180000  46.150002  46.919998  47.080002  16296700.0  34.811729
# 2006-01-04  47.240002  46.450001  47.000000  46.580002  17757900.0  34.442013
# 2006-01-05  46.830002  46.320000  46.580002  46.639999  14970700.0  34.486385
# 2006-01-06  46.910000  46.349998  46.799999  46.570000  12599800.0  34.434616
# 2006-01-09  46.970001  46.360001  46.720001  46.599998  15619400.0  34.456806
# ...               ...        ...        ...        ...         ...        ...
# 2017-12-22  30.030001  29.620001  29.980000  29.879999  54203000.0  28.112759
# 2017-12-26  29.940001  29.580000  29.740000  29.780001  42371200.0  28.018675
# 2017-12-27  29.730000  29.600000  29.660000  29.730000  35111800.0  27.971630
# 2017-12-28  29.820000  29.660000  29.730000  29.799999  37914900.0  28.037491
# ...

# %%
#Set the column name levels
bank_stocks.columns.names = ['Bank Ticker','Stock Info']

# %%
bank_stocks
# Out:
# Bank Ticker        BAC                                               \
# Stock Info        High        Low       Open      Close      Volume
# Date
# 2006-01-03   47.180000  46.150002  46.919998  47.080002  16296700.0
# 2006-01-04   47.240002  46.450001  47.000000  46.580002  17757900.0
# 2006-01-05   46.830002  46.320000  46.580002  46.639999  14970700.0
# 2006-01-06   46.910000  46.349998  46.799999  46.570000  12599800.0
# 2006-01-09   46.970001  46.360001  46.720001  46.599998  15619400.0
# ...                ...        ...        ...        ...         ...
# 2017-12-22   30.030001  29.620001  29.980000  29.879999  54203000.0
# 2017-12-26   29.940001  29.580000  29.740000  29.780001  42371200.0
# 2017-12-27   29.730000  29.600000  29.660000  29.730000  35111800.0
# 2017-12-28   29.820000  29.660000  29.730000  29.799999  37914900.0
# 2017-12-29   29.879999  29.520000  29.850000  29.520000  40672000.0
#
# ...

# %% [markdown]
# # EDA

# %%
#the max Close price for each bank's stock throughout the time period
bank_stocks.xs(key='Close',axis=1,level='Stock Info').max()
# Out:
# Bank Ticker
# BAC     54.900002
# C      564.099976
# GS     261.010010
# JPM    107.830002
# MS      89.300003
# WFC     61.610001
# dtype: float64

# %%
#the returns for each bank's stock.
returns = pd.DataFrame()

for tick in tickers:
    returns[tick+'Return']= bank_stocks[tick]['Close'].pct_change()

# %%
returns.head()
# Out:
#             BACReturn   CReturn  GSReturn  JPMReturn  MSReturn  WFCReturn
# Date
# 2006-01-03        NaN       NaN       NaN        NaN       NaN        NaN
# 2006-01-04  -0.010620 -0.018462 -0.013812  -0.014183  0.000686  -0.011599
# 2006-01-05   0.001288  0.004961 -0.000393   0.003029  0.002742  -0.001110
# 2006-01-06  -0.001501  0.000000  0.014169   0.007046  0.001025   0.005874
# 2006-01-09   0.000644 -0.004731  0.012030   0.016242  0.010586  -0.000158

# %%
sns.pairplot(returns[1:])

# %% [raw]
# See solution for details about Citigroup behavior....

# %%
#Using this returns DataFrame,let figure out on what dates each bank stock had the best and worst single day returns.
returns.idxmin()
# Out:
# BACReturn   2009-01-20
# CReturn     2009-02-27
# GSReturn    2009-01-20
# JPMReturn   2009-01-20
# MSReturn    2008-10-09
# WFCReturn   2009-01-20
# dtype: datetime64[ns]

# %%
returns.idxmax()
# Out:
# BACReturn   2009-04-09
# CReturn     2008-11-24
# GSReturn    2008-11-24
# JPMReturn   2009-01-21
# MSReturn    2008-10-13
# WFCReturn   2008-07-16
# dtype: datetime64[ns]

# %%
returns.std()
# Out:
# BACReturn    0.034183
# CReturn      0.035917
# GSReturn     0.023954
# JPMReturn    0.025823
# MSReturn     0.035234
# WFCReturn    0.028128
# dtype: float64

# %% [markdown]
#  Citigroup's largest drop and biggest gain were very close to one another, did anythign significant happen in that time frame?
#  ake a look at the standard deviation of the returns, which stock would you classify as the riskiest over the entire time period?Which would you classify as the riskiest for the year 2008?**

# %%
returns.loc['2008-01-01':'2009-01-01'].std()
# Out:
# BACReturn    0.062934
# CReturn      0.073523
# GSReturn     0.050015
# JPMReturn    0.053134
# MSReturn     0.087604
# WFCReturn    0.052439
# dtype: float64

# %% [markdown]
# Create a distplot using seaborn of the 2008 returns for Morgan Stanley

# %%
sns.distplot(returns.loc['2008-01-01':'2009-01-01']['MSReturn'],color='green',bins=50)

# %% [markdown]
# Create a distplot using seaborn of the 2008 returns for CitiGroup

# %%
sns.distplot(returns.loc['2008-01-01':'2009-01-01']['CReturn'],color='red',bins=50)

# %% [markdown]
# # More Visualization

# %% [markdown]
# Imports

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# Optional Plotly Method Imports
import plotly
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
bank_stocks.xs(key='Close',axis=1,level='Stock Info').plot()
plt.legend()

# %%
bank_stocks.xs(key='Close',axis=1,level='Stock Info').iplot()
# Out:
# <div>                            <div id="813a98c6-d058-4ba2-bb43-95003bd73501" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # Moving Averages

# %% [markdown]
# Let's analyze the moving averages for these stocks in the year 2008.

# %%
plt.figure(figsize=(12,4))
C['Close'].loc['2008-01-01':'2009-01-01'].rolling(window=30).mean().plot(label='30 Day Avg')
C['Close'].loc['2008-01-01':'2009-01-01'].plot(label='C Close')
plt.legend()

# %% [markdown]
# CitiGroup's stock from Jan 1st 2008 to Jan 1st 2009

# %%
C08=C[['Open','High','Low','Close']].loc['2008-01-01':'2009-01-01']
C08.iplot(kind='candle')
# Out:
# <div>                            <div id="3a3dcc45-6a5e-45ef-9338-156f5124a835" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# Simple Moving Averages plot of Morgan Stanley the year 2008

# %%
MS['Close'].loc['2008-01-01':'2009-01-01'].ta_plot(study='sma',periods=[13,21,55])
# Out:
# <div>                            <div id="6b613488-13c7-48fe-92a0-eed0cacec363" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# Bollinger Band Plot for Bank of America for the year 2008

# %%
BAC['Close'].loc['2008-01-01':'2009-01-01'] .ta_plot(study='boll')
# Out:
# <div>                            <div id="3636e3fe-e484-4389-9a10-87b685f1cb94" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
